# %%
# import the necessary packages
from skimage.measure import compare_ssim
import cv2

ll = []
for i in range(1979):
    first = "C:\\Users\hanisha\Desktop\sir\data\\frame"+str(i)+".jpg"
    second = "C:\\Users\hanisha\Desktop\sir\data\\frame"+str(i+1)+".jpg"
    # load the two input images
    imageA = cv2.imread(first)
    imageB = cv2.imread(second)

    # convert the images to grayscale
    grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
    grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)

    # compute the Structural Similarity Index (SSIM) between the two
    # images, ensuring that the difference image is returned
    (score, diff) = compare_ssim(grayA, grayB, full=True)
    diff = (diff * 255).astype("uint8")
    print("SSIM: {}".format(score))

    ll.append(score)
# Out:
# SSIM: 0.9998582070384755
# SSIM: 0.9822090015836907
# SSIM: 0.9837517622264847
# SSIM: 0.990867617379685
# SSIM: 0.985947865281124
# SSIM: 0.9883314389186149
# SSIM: 0.9862999499220635
# SSIM: 0.9878026074693095
# SSIM: 0.9877926099198505
# SSIM: 0.9903413076538178
# SSIM: 0.985467181548729
# SSIM: 0.9830972500138067
# SSIM: 0.9764004053626508
# SSIM: 0.9838910055823717
# SSIM: 0.9839562823043018
# SSIM: 0.9883260371283646
# SSIM: 0.9846656468617808
# SSIM: 0.9912484406996344
# SSIM: 0.9847281585196931
# SSIM: 0.9899798729254412
# SSIM: 0.9845041840733578
# SSIM: 0.989240719192738
# SSIM: 0.9848371765837078
# SSIM: 0.9899107884090795
# SSIM: 0.9890571471253584
# SSIM: 0.9898008773618786
# SSIM: 0.9931825010167376
# SSIM: 0.9876443520828702
# SSIM: 0.9899584504677345
# SSIM: 0.986039547921675
# SSIM: 0.9913359520625498
# SSIM: 0.9866256115530926
# SSIM: 0.9885480530168006
# SSIM: 0.9881108330324717
# SSIM: 0.9880616644044607
# SSIM: 0.9831782033465425
# SSIM: 0.9919435520788089
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
# plt.axhline(y=0.42,color='gray',linestyle='--')
plt.plot(np.array(ll))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
# plt.axhline(y=0.42,color='gray',linestyle='--')

plt.plot(np.array(np.sort(ll)))
plt.show()

ind = np.argpartition(ll, 10)[:10]
print("indices are: ",ind)
# Out:
# <img src="data:image/png;base64,..." width="640">
# indices are:  [ 258 1018  209  817  373 1915  875 1054 1098  649]

# %%
import os

# define the name of the directory to be created
path = "C:\\Users\hanisha\Desktop\sir\key_frames"

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Creation of the directory C:\Users\hanisha\Desktop\sir\key_frames failed

# %%
import shutil
import os

source = "C:\\Users\hanisha\Desktop\sir\data"
dest = "C:\\Users\hanisha\Desktop\sir\key_frames"

# %%
for i in ind:
    print (i)
    src = source+"\\frame"+str(i)+".jpg"
    dst = dest+"\\frame"+str(i)+".jpg"
    shutil.copy(src, dst)
print("sucessfully copied...")
# Out:
# 258
# 1018
# 209
# 817
# 373
# 1915
# 875
# 1054
# 1098
# 649
# sucessfully copied...

# %%
from skimage.measure import compare_ssim
import cv2

bb = []
for i in range(0,1979,32):
    first = "C:\\Users\hanisha\Desktop\sir\data\\frame"+str(i)+".jpg"
    second = "C:\\Users\hanisha\Desktop\sir\data\\frame"+str(i+32)+".jpg"
    # load the two input images
    imageA = cv2.imread(first)
    imageB = cv2.imread(second)

    # convert the images to grayscale
    grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
    grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)

    # compute the Structural Similarity Index (SSIM) between the two
    # images, ensuring that the difference image is returned
    (score, diff) = compare_ssim(grayA, grayB, full=True)
    diff = (diff * 255).astype("uint8")
    print("SSIM: {}".format(score))

    bb.append(score)
# Out:
# SSIM: 0.9613435419962261
# SSIM: 0.9637778004803691
# SSIM: 0.9594970602309171
# SSIM: 0.9570718581236243
# SSIM: 0.9624939369159297
# SSIM: 0.962671620572508
# SSIM: 0.9626804643030792
# SSIM: 0.9631448904033211
# SSIM: 0.964570955964984
# SSIM: 0.9660099973722667
# SSIM: 0.9641207906586343
# SSIM: 0.9654363599883663
# SSIM: 0.9569720379527763
# SSIM: 0.9566188534640355
# SSIM: 0.9617330770976534
# SSIM: 0.9619367066717326
# SSIM: 0.9623592092974692
# SSIM: 0.9618936767248961
# SSIM: 0.9605705629115306
# SSIM: 0.9602719194254455
# SSIM: 0.9595682059629146
# SSIM: 0.959773266137761
# SSIM: 0.9586655131341848
# SSIM: 0.9599175382772682
# SSIM: 0.9607124419195024
# SSIM: 0.956178157381343
# SSIM: 0.9558973917817961
# SSIM: 0.9567430653034134
# SSIM: 0.9517844734008641
# SSIM: 0.9484952158358104
# SSIM: 0.9480884326490602
# SSIM: 0.9510402671917952
# SSIM: 0.9483518345544871
# SSIM: 0.9540990228381542
# SSIM: 0.9558284580220143
# SSIM: 0.9543337802724209
# SSIM: 0.9595053146089729
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
# plt.axhline(y=0.42,color='gray',linestyle='--')
plt.plot(np.array(bb))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from skimage.measure import compare_ssim
import cv2

k = []
difference = 32
for i in range(0,1979-difference,difference):
    first = "C:\\Users\hanisha\Desktop\sir\data\\frame"+str(i)+".jpg"
    second = "C:\\Users\hanisha\Desktop\sir\data\\frame"+str(i+difference)+".jpg"
    # load the two input images
    imageA = cv2.imread(first)
    imageB = cv2.imread(second)

    # convert the images to grayscale
    grayA = cv2.cvtColor(imageA, cv2.COLOR_BGR2GRAY)
    grayB = cv2.cvtColor(imageB, cv2.COLOR_BGR2GRAY)

    # compute the Structural Similarity Index (SSIM) between the two
    # images, ensuring that the difference image is returned
    (score, diff) = compare_ssim(grayA, grayB, full=True)
    diff = (diff * 255).astype("uint8")
    print("SSIM: {}".format(score), i)

    k.append((score,i))
    
k = np.array(k)
# Out:
# SSIM: 0.9613435419962261 0
# SSIM: 0.9483518345544871 32
# SSIM: 0.35408022668829625 64
# SSIM: 0.9448193567303955 96
# SSIM: 0.9681273737013459 128
# SSIM: 0.9479355380578542 160
# SSIM: 0.2718135446655762 192
# SSIM: 0.8190713334034244 224
# SSIM: 0.275704372839629 256
# SSIM: 0.9650511729396325 288
# SSIM: 0.9425541687712988 320
# SSIM: 0.2919302716204675 352
# SSIM: 0.5329871646394706 384
# SSIM: 0.5745924378165603 416
# SSIM: 0.56296966631413 448
# SSIM: 0.6614434250822177 480
# SSIM: 0.6772428272762504 512
# SSIM: 0.7877144296772945 544
# SSIM: 0.7661575092202115 576
# SSIM: 0.6872386768332335 608
# SSIM: 0.3303320336579775 640
# SSIM: 0.47175696500756303 672
# SSIM: 0.6075445433893635 704
# SSIM: 0.6339714636719862 736
# SSIM: 0.6363126068397814 768
# SSIM: 0.24150853392421656 800
# SSIM: 0.8060682503421327 832
# SSIM: 0.225724815822665 864
# SSIM: 0.9767567814790425 896
# SSIM: 0.9720447050386573 928
# SSIM: 0.032214914498526884 960
# SSIM: 0.13120547742444563 992
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
# plt.axhline(y=0.42,color='gray',linestyle='--')
plt.plot(k[:,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.array(np.sort(k[:, 0])))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.sort(k[:, 0])
# Out:
# array([0.03221491, 0.13120548, 0.22572482, 0.24150853, 0.27181354,
#        0.27570437, 0.29193027, 0.30885035, 0.32749552, 0.33033203,
#        0.33225277, 0.34703058, 0.35408023, 0.35668271, 0.35978088,
#        0.38283643, 0.38926938, 0.39002407, 0.39804012, 0.4206005 ,
#        0.47175697, 0.49695682, 0.52301964, 0.53298716, 0.55732347,
#        0.56296967, 0.57459244, 0.57971776, 0.59354365, 0.60075849,
#        0.60754454, 0.62171993, 0.63397146, 0.63631261, 0.64534241,
#        0.64929436, 0.65428721, 0.66144343, 0.67420219, 0.67724283,
#        0.68723868, 0.74445031, 0.76615751, 0.78718553, 0.78771443,
#        0.79202617, 0.79761879, 0.80606825, 0.81907133, 0.83479128,
#        0.91848427, 0.93090527, 0.94255417, 0.94481936, 0.94793554,
#        0.94835183, 0.96134354, 0.96505117, 0.96812737, 0.97204471,
#        0.97675678])

# %%
import pandas as pd
val = sorted(k,key=lambda x: x[0])
fil = val[:10]
print(fil)
# Out:
# [array([3.22149145e-02, 9.60000000e+02]), array([1.31205477e-01, 9.92000000e+02]), array([2.25724816e-01, 8.64000000e+02]), array([2.41508534e-01, 8.00000000e+02]), array([  0.27181354, 192.        ]), array([  0.27570437, 256.        ]), array([2.91930272e-01, 3.52000000e+02]), array([3.08850347e-01, 1.08800000e+03]), array([3.27495516e-01, 1.02400000e+03]), array([3.30332034e-01, 6.40000000e+02])]

# %%
f = (np.int_(fil))
print(f)
f[:,1]
# Out:
# [[   0  960]
#  [   0  992]
#  [   0  864]
#  [   0  800]
#  [   0  192]
#  [   0  256]
#  [   0  352]
#  [   0 1088]
#  [   0 1024]
#  [   0  640]]
# array([ 960,  992,  864,  800,  192,  256,  352, 1088, 1024,  640])

# %%
import os

# define the name of the directory to be created
path = "C:\\Users\hanisha\Desktop\sir\key_frames1"

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory C:\Users\hanisha\Desktop\sir\key_frames1

# %%
import shutil
import os

source = "C:\\Users\hanisha\Desktop\sir\data"
dest = "C:\\Users\hanisha\Desktop\sir\key_frames1"
for i in f[:,1]:
    print (i)
    src = source+"\\frame"+str(i)+".jpg"
    dst = dest+"\\frame"+str(i)+".jpg"
    shutil.copy(src, dst)
print("sucessfully copied...")
# Out:
# 960
# 992
# 864
# 800
# 192
# 256
# 352
# 1088
# 1024
# 640
# sucessfully copied...
